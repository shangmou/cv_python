# %%
import cv2 # 默认读取BGR # cv2.IMREAD_COLOR彩色图像    cv2.IMREAD_GRAYSCALE灰度图像
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

img = cv2.imread('50.jpg')

# %%
img
# Out:
# array([[[141, 151, 191],
#         [145, 155, 195],
#         [143, 156, 194],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[142, 152, 192],
#         [143, 153, 193],
#         [142, 155, 193],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[142, 152, 192],
#         [141, 151, 191],
#         [142, 153, 191],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 96, 137, 170],
#         [ 94, 135, 168],
#         [ 92, 131, 163],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 99, 140, 173],
#         [ 97, 138, 171],
#         [ 96, 134, 166],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[100, 141, 174],
#         [100, 141, 174],
#         [ 98, 136, 168],
# ...

# %%
cv2.imshow('image',img)
# 等待时间，毫秒，0表示任意键终止
cv2.waitKey(0)
cv2.destroyAllWindows() # win打开

# %%
def cv_show(name,img):
    cv2.imshow(name,img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
img.shape # h,w,c
# Out:
# (999, 666, 3)

# %%
img = cv2.imread('01.jpg',cv2.IMREAD_GRAYSCALE)
img
# Out:
# array([[123, 122, 121, ..., 190, 190, 190],
#        [123, 122, 121, ..., 190, 190, 190],
#        [122, 122, 121, ..., 190, 190, 190],
#        ...,
#        [182, 182, 182, ...,  38,  38,  40],
#        [182, 182, 182, ...,  39,  40,  41],
#        [182, 182, 182, ...,  40,  40,  41]], dtype=uint8)

# %%
img.shape
# Out:
# (854, 640)

# %% [markdown]
# #  数据读取--视频

# %%
vc = cv2.VideoCapture('11.mp4')

# %%
# 检查是否打开正确
if vc.isOpened():
    open,frame = vc.read()
else:
    open = False

# %%
while open:
    ret,frame = vc.read()
    # 为空
    if frame is None:
        break
    if ret ==True:
        # 转为灰度图
        gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY) 
        cv2.imshow('result',gray)
        if cv2.waitKey(10) & 0xFF == 27:
            break
vc.release()
cv2.destroyAllWindows()

# %% [markdown]
# #  截取图像数据

# %%
img = cv2.imread('02.jpg')
gril = img[0:2000,0:1000]
cv_show('gril',gril)

# %% [markdown]
# # 颜色通道提取

# %%
b,g,r = cv2.split(img)

# %%
b
# Out:
# array([[ 73,  72,  71, ..., 130, 137,  72],
#        [ 71,  70,  70, ..., 130, 137,  72],
#        [ 66,  66,  67, ..., 130, 137,  72],
#        ...,
#        [139, 139, 139, ..., 122, 117,  65],
#        [139, 139, 139, ..., 123, 119,  67],
#        [139, 139, 139, ..., 126, 123,  71]], dtype=uint8)

# %%
b.shape
# Out:
# (1280, 960)

# %%
img=cv2.merge((b,g,r))
img.shape
# Out:
# (1280, 960, 3)

# %%
# 只保留 R
cur_img = img.copy()
cur_img[:,:,0] = 0 # B
cur_img[:,:,1] = 0 # G
cv_show('R',cur_img)

# %% [markdown]
# #  边界填充

# %%
top_size,bottom_size,left_size,right_size = (50,50,50,50)

# 复制法--复制最边缘的像素
# 反射法--对感兴趣的图像中的像素的两边进行复制,如：fedcba\abcdefgh\hgfedcb
# 
replicate = cv2.copyMakeBorder(img,top_size,bottom_size,left_size,right_size,borderType=cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img,top_size,bottom_size,left_size,right_size,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, cv2.BORDER_WRAP)
constant = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size,cv2.BORDER_CONSTANT, value=0)

# %%
import matplotlib.pyplot as plt
plt.subplot(231),plt.imshow(img,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233), plt.imshow(reflect, 'gray'), plt.title('REFLECT')
plt.subplot(234), plt.imshow(reflect101, 'gray'), plt.title('REFLECT_101')
plt.subplot(235), plt.imshow(wrap, 'gray'), plt.title('WRAP')
plt.subplot(236), plt.imshow(constant, 'gray'), plt.title('CONSTANT')

plt.show()

# %% [markdown]
# •BORDER_REPLICATE：复制法，也就是复制最边缘像素。
#
# •BORDER_REFLECT：反射法，对感兴趣的图像中的像素在两边进行复制例如：fedcba|abcdefgh|hgfedcb
#
# •BORDER_REFLECT_101：反射法，也就是以最边缘像素为轴，对称，gfedcb|abcdefgh|gfedcba
#
# •BORDER_WRAP：外包装法cdefgh|abcdefgh|abcdefg
#
# •BORDER_CONSTANT：常量法，常数值填充。

# %% [markdown]
# # 数值计算

# %%
img_52 = cv2.imread('52.jpg')
img_53 = cv2.imread('32.jpg')

# %%
img_52_10 = img_52 +10 # 每个像素点加 10
img_52[:5,:,0]
# Out:
# array([[ 54,  52,  51, ..., 198, 198, 198],
#        [ 54,  52,  51, ..., 197, 197, 197],
#        [ 53,  52,  51, ..., 197, 197, 197],
#        [ 53,  51,  50, ..., 196, 196, 196],
#        [ 54,  51,  50, ..., 196, 196, 196]], dtype=uint8)

# %%
img_52_10[:5,:,0]
# Out:
# array([[ 64,  62,  61, ..., 208, 208, 208],
#        [ 64,  62,  61, ..., 207, 207, 207],
#        [ 63,  62,  61, ..., 207, 207, 207],
#        [ 63,  61,  60, ..., 206, 206, 206],
#        [ 64,  61,  60, ..., 206, 206, 206]], dtype=uint8)

# %%
# 超过256，%256，余数
(img_52 + img_52_10)[:5,:,0]
# Out:
# array([[118, 114, 112, ..., 150, 150, 150],
#        [118, 114, 112, ..., 148, 148, 148],
#        [116, 114, 112, ..., 148, 148, 148],
#        [116, 112, 110, ..., 146, 146, 146],
#        [118, 112, 110, ..., 146, 146, 146]], dtype=uint8)

# %%
cv2.add(img_52,img_52_10)[:5,:,0]
# Out:
# array([[118, 114, 112, ..., 255, 255, 255],
#        [118, 114, 112, ..., 255, 255, 255],
#        [116, 114, 112, ..., 255, 255, 255],
#        [116, 112, 110, ..., 255, 255, 255],
#        [118, 112, 110, ..., 255, 255, 255]], dtype=uint8)

# %% [markdown]
# # 图像融合

# %%
(img_52 + img_53)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-76209bed1664> in <module>()
# ----> 1 (img_52 + img_53)
#
# ValueError: operands could not be broadcast together with shapes (666,999,3) (999,666,3)

# %%
img_52.shape
# Out:
# (1998, 2997, 3)

# %%
img_53 = cv2.resize(img_52,(2997,1998))
img_53.shape
# Out:
# (1998, 2997, 3)

# %%
res = cv2.addWeighted(img_52, 0.4, img_53, 0.6, 0)

# %%
plt.imshow(res)

# %%
res = cv2.resize(img,(0,0),fx=3,fy=1) # x1*w1+x2*w2 + b---b偏置，亮度
plt.imshow(res)
